# %%
import os

import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet

# %%
sns.set()

# %%
FILE_PATH = "diario/PRECIP_PT/"
DATA_FILES = [os.path.join(FILE_PATH,i) for i in next(os.walk(FILE_PATH))[2]]

# %%
date = pd.Series(dtype=np.int64)
precip = pd.Series(dtype=np.float64)
for f in DATA_FILES:
    data = pd.read_fwf(f, sep="\t", header=None)
    #select lisbon data
    data = data[((data[0]==38.8) & (data[1]==-9.2))|(data[0]>1000)].reset_index()
    date = pd.concat([date,data[0].iloc[::2].astype(np.int64)],ignore_index=True)
    precip = pd.concat([precip,data[2].iloc[1::2]],ignore_index=True)

# %%
d = {'ds':date,'y':precip}
data = pd.DataFrame(data=d)
data["ds"] = pd.to_datetime(data["ds"],format="%Y%m%d")
data.dropna(inplace=True)
data.sort_values(by=['ds'],inplace=True)

# %%
data
# Out:
#               ds     y
# 0     1950-01-02  0.00
# 1     1950-01-03  0.00
# 2     1950-01-04  0.00
# 3     1950-01-05  0.00
# 4     1950-01-06  0.00
# ...          ...   ...
# 19717 2003-12-27  0.00
# 19718 2003-12-28  2.44
# 19719 2003-12-29  0.03
# 19720 2003-12-30  0.06
# 19721 2003-12-31  0.00
#
# [19722 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19722 entries, 0 to 19721
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      19722 non-null  datetime64[ns]
#  1   y       19722 non-null  float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 462.2 KB

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=data,x='ds', y='y')
plt.show()

# %%
m = Prophet()

# %%
model = m.fit(data)
# Out:
# 22:26:39 - cmdstanpy - INFO - Chain [1] start processing
# 22:26:40 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=20*365)
forecast = m.predict(future)

# %%
m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)
